# %%
offset_track = 5
batch_size = 2

count = range(offset_track, offset_track + batch_size)
print(count.count)
print(count.start)
print(count.stop)
# Out:
# <built-in method count of range object at 0x00000127EF4E3120>
# 5
# 7
